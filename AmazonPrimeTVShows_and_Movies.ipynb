# %% [markdown]
# # **Project Name**    - Exploratory Data Analysis on Amazon Prime TV Shows and Movies

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project, I performed **Exploratory Data Analysis (EDA)** on the Amazon Prime Movies and TV Shows dataset to understand content trends, patterns, and relationships between different variables.
#
# **Datasets Used**
#
# **Titles Dataset:** 9,871 records covering title, type, genre, runtime, release year, and ratings.
#
# **Credits Dataset:** 124,000+ entries detailing actors, directors, and their roles.
#
# Using **Pandas** and **NumPy**, I cleaned and prepared the dataset by handling missing values, correcting data types, managing duplicates, and transforming columns where necessary. This ensured the dataset was structured and ready for analysis.
#
# With the help of **Matplotlib** , **Seaborn** and **Plotly** I created various visualizations to explore:
#
# - Distribution of movies and TV shows
#
# - Release year trends
#
# - Runtime distribution and detection of short-duration outliers
#
# - IMDb score and vote patterns
#
# - Content production by country
#
# Correlation between numerical features such as IMDb score, votes, runtime, and popularity
#
# I performed both **univariate analysis** (distribution of individual features) and **bivariate analysis** (relationships between two variables), including heatmaps to understand correlation strength between numerical variables.
#
#  **Key Insights Gained**:
#
# **1. Content Portfolio is Movie-Dominant**
#
# The platform’s catalog is heavily skewed toward movies **(86.3%)** compared to TV shows **(13.7%)**. While TV shows tend to span multiple seasons, they represent a smaller portion of total titles. This indicates a content strategy focused primarily on standalone film distribution.
#
# **2. Strong Content Expansion After 2015**
#
# There is a noticeable surge almost **50%** in content additions in recent years, particularly post-2015. This suggests an aggressive acquisition and production strategy aligned with the rapid growth of streaming competition and digital consumption trends.
#
# **3. Standardized Runtime Pattern with Short-Form Presence**
#
# Most movies fall within the **80–120** minute range, reflecting industry standards for feature-length films. However, the dataset contains a significant number of titles under 15 minutes, likely representing short films, special episodes, or non-standard entries. The runtime distribution is slightly right-skewed, indicating a small number of very long titles.
#
# **4. Weak Correlation Between IMDb Votes and Ratings**
#
# The correlation between IMDb votes and IMDb score is weakly positive. While higher vote counts improve rating reliability, they do not necessarily lead to higher ratings. This highlights that popularity and perceived quality are distinct metrics.
#
# **5. Popularity Does Not Guarantee Quality**
#
# TMDB popularity shows limited correlation with IMDb score. Highly marketed or trending content does not always receive strong audience ratings, indicating that visibility and user satisfaction are influenced by different factors.
#
# **6. Country-Wise Production Concentration**
#
# Content production is concentrated in a few dominant countries, with the United States **(59.6%)** contributing the largest share. Emerging markets such as India **(12%)** show increasing representation, suggesting opportunities for regional expansion strategies.
#
# **7. Rating Reliability Improves with Vote Thresholds**
#
# Titles with very low vote counts display higher rating variability. Applying a minimum vote threshold enhances the reliability of rating-based analysis and prevents skewed interpretations from niche or recently released titles.
#
# **8. Data Quality Observations**
#
# The dataset contains missing values in attributes such as age certification **(65%)** and seasons **(86%)**. Duplicate records and runtime anomalies were identified and addressed, improving the accuracy and credibility of analytical findings
#
# This project strengthened my understanding of:
#
# - Data cleaning techniques
#
# - Feature distribution analysis
#
# - Correlation analysis
#
# - Visualization best practices
#
# - Interpreting real-world entertainment data
#
# Overall, this EDA helped uncover meaningful insights about Amazon Prime content and improved my practical skills in data preprocessing, visualization, and analytical thinking using Python

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such as:
#
# - Content Diversity: What genres and categories dominate the platform?
# - Regional Availability: How does content distribution vary across different regions?
# - Trends Over Time: How has Amazon Prime’s content library evolved?
# - IMDb Ratings & Popularity: What are the highest-rated or most popular shows on the platform?
#
# By analyzing this dataset, businesses, content creators, and data analysts can uncover key trends that influence subscription growth, user engagement, and content investment strategies in the streaming industry.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# This project aims to analyze Amazon Prime Video’s catalog to uncover insights into audience preferences, content diversity, and market trends.
#
# By exploring genres, regions, release patterns, ratings, and cast/crew data, the goal is to:
#
# Enhance content strategy by identifying high-performing genres and regions.
#
# Boost audience engagement through data-driven recommendations.
#
# Drive business growth by aligning content investments with viewer demand.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
#Credits dataset
credits=pd.read_csv('/content/credits.csv (1).zip')
#Titles dataset
titles=pd.read_csv('/content/titles.csv.zip')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
#Titles
titles
# Out:
#              id                            title   type  \
# 0       ts20945                The Three Stooges   SHOW
# 1       tm19248                      The General  MOVIE
# 2       tm82253      The Best Years of Our Lives  MOVIE
# 3       tm83884                  His Girl Friday  MOVIE
# 4       tm56584                In a Lonely Place  MOVIE
# ...         ...                              ...    ...
# 9866   tm510327                     Lily Is Here  MOVIE
# 9867  tm1079144  Jay Nog: Something from Nothing  MOVIE
# 9868   tm847725                          Chasing  MOVIE
# 9869  tm1054116                         Baikunth  MOVIE
# 9870   ts275838                 Waking Up Eighty   SHOW
#
#                                             description  release_year  \
# 0     The Three Stooges were an American vaudeville ...          1934
# 1     During America’s Civil War, Union spies steal ...          1926
# 2     It's the hope that sustains the spirit of ever...          1946
# ...

# %%
#Credit
credits
# Out:
#         person_id         id           name      character      role
# 0           59401    ts20945     Joe Besser            Joe     ACTOR
# 1           31460    ts20945     Moe Howard            Moe     ACTOR
# 2           31461    ts20945     Larry Fine          Larry     ACTOR
# 3           21174    tm19248  Buster Keaton    Johnny Gray     ACTOR
# 4           28713    tm19248    Marion Mack  Annabelle Lee     ACTOR
# ...           ...        ...            ...            ...       ...
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
#
# [124235 rows x 5 columns]

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#Titles
titles.shape
# Out:
# (9871, 15)

# %%
# Dataset Rows & Columns count
#Credits
credits.shape
# Out:
# (124235, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
#Titles
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
# Dataset Info
#Credits
credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
#Titles
titles.duplicated().sum()
# Out:
# np.int64(3)

# %%
#Credits
credits.duplicated().sum()
# Out:
# np.int64(56)

# %%
# checking if the duplicates are real
titles[titles.duplicated(keep=False)]
# Out:
#            id                  title   type  \
# 479   tm89134  The Gunman From Bodie  MOVIE
# 480   tm89134  The Gunman From Bodie  MOVIE
# 718   tm66674               Dynamite  MOVIE
# 719  tm137955          Broken Dreams  MOVIE
# 720   tm66674               Dynamite  MOVIE
# 722  tm137955          Broken Dreams  MOVIE
#
#                                            description  release_year  \
# 479  The Rough Riders are after a gang of rustlers....          1941
# 480  The Rough Riders are after a gang of rustlers....          1941
# 718  Two members of a dynamite crew--a rugged veter...          1949
# 719  Medical intern Robert Morley is distraught aft...          1933
# 720  Two members of a dynamite crew--a rugged veter...          1949
# 722  Medical intern Robert Morley is distraught aft...          1933
#
#     age_certification  runtime                genres production_countries  \
# 479               NaN       62           ['western']               ['US']
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
#Titles
titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6484
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8511
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2080
# dtype: int64

# %%
# Missing Values/Null Values Count
# Credits
credits.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64

# %%
# Visualizing the missing values in Titles dataset
plt.figure(figsize=(10, 6))
sns.heatmap(titles.isnull(), cmap = 'viridis',cbar = False, yticklabels = False)
plt.title('Missing values Heatmap')
# Out:
# Text(0.5, 1.0, 'Missing values Heatmap')

# %%
# Visualizing the missing values in Credit dataset
plt.figure(figsize=(10, 6))
sns.heatmap(credits.isnull(), cmap = 'viridis',cbar = False, yticklabels = False)
plt.title('Missing values Heatmap')
# Out:
# Text(0.5, 1.0, 'Missing values Heatmap')

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# **Dataset Overview**
#
# The dataset used in this project comes from Amazon Prime Video’s catalog (U.S. region) 🇺🇸 — originally in two raw files: titles.csv  and credits.csv.
#
#  **Dataset Size & Structure**
#
# Titles Dataset: 9,871 unique shows & movies with 15 attributes.
#
# Credits Dataset: 124,235 records of cast and crew  with 5 attributes.
#
#  **Types of Variables**
#
# **Categorical Variables**: Content type (Movie/Show), Age Certification, Genres, Production Countries, Role (Actor/Director).
#
# **Numerical Variables**: Release Year, Runtime, Number of Seasons, IMDb/TMDB Ratings, IMDb Votes, TMDB Popularity.
#
# **Text Variables**: Title, Description, Name, Character.
#
# **Content Composition**
#
# The catalog includes both movies and TV shows.
#
# Genres are diverse (Drama, Comedy, Action, Thriller, Documentary).
#
# Content originates from multiple production countries, with the U.S. 🇺🇸 being dominant.
#
#  **Ratings & Popularity**
#
# Most titles feature IMDb and TMDB ratings — allowing assessment of audience reception.
#
# TMDB popularity scores offer insights into trending content.
#
#  **Cast & Crew Data**
#
# The credits dataset enriches analysis by linking actors and directors to titles.
#
# This enables identification of the most frequent actors/directors and collaboration patterns.
#
# **Data Quality & Cleaning**
#
# Raw datasets had missing values, outliers and inconsistencies (e.g., missing runtimes, null age certifications, duplicate records).
#
# **Wrangling steps included:**
#
# Handling null values (imputation or removal).
#
# Removing or capping outliers (extreme runtimes or unrealistic ratings).
#
# Standardising categorical variables (genres, countries).
#
# Merging duplicates and ensuring consistency across datasets.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print('Titles Dataset Columns:\n')
print(titles.columns)
print('----------------')
print('Credits Dataset Columns:\n')
print(credits.columns)
# Out:
# Titles Dataset Columns:
#
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')
# ----------------
# Credits Dataset Columns:
#
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# Dataset Describe
print('Titles Dataset Describe:\n')
print(titles.describe())
print('----------------')
print('Credits Dataset Describe:\n')
print(credits.describe(include = 'all'))
# Out:
# Titles Dataset Describe:
#
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9868.000000  9868.000000  1357.000000  8847.000000  8.837000e+03
# mean    2001.345561    85.979124     2.791452     5.976534  8.536485e+03
# std       25.792295    33.515714     4.148958     1.344028  4.592768e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1996.000000    65.000000     1.000000     5.100000  1.180000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.640000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.237000e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9321.000000  7788.000000
# mean          6.912168     5.984117
# std          30.008727     1.518040
# min           0.000011     0.800000
# 25%           1.234000     5.100000
# 50%           2.537000     6.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# The dataset consists of two files — titles.csv and credits.csv — which were merged into a consolidated dataframe (df) for analysis. Below is the description of the key variables:
#
# **Titles Dataset (titles.csv)**
#
# Contains metadata of TV shows and movies available on Amazon Prime.
#
# id : Unique identifier of the title (on JustWatch).
#
# title : Name of the movie or TV show.
#
# type : Content type: Movie or TV Show.
#
# description : Brief synopsis of the title.
#
# release_year : Year in which the title was released.
#
# age_certification : Age rating (e.g., PG, R, 18+).
#
# runtime : Duration of the movie or average length of an episode (in minutes).
#
# genres : List of genres (Drama, Comedy, Action, etc.).
#
# production_countries : Countries involved in producing the title.
#
# seasons : Number of seasons (only for TV shows).
#
# imdb_id : Unique IMDb identifier.
#
# imdb_score : IMDb rating score (0–10).
#
# imdb_votes : Number of IMDb user votes.
#
# tmdb_popularity : Popularity score from TMDB.
#
# tmdb_score : TMDB rating score.
#
# **Credits Dataset (credits.csv)**
#
# Contains cast and crew details for each title.
#
# person_id : Unique identifier for an actor/director.
#
# id : Title ID (to link with titles dataset).
#
# name : Name of the person (actor or director).
#
# character : Character played (if actor).
#
# role : Role in the production (ACTOR or DIRECTOR).

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
#Check count of unique values for each variable
print('Count of unique values in Titles Dataset--------')
for col in titles.columns:
  count = titles[col].nunique()
  print(f'{col} : {count}')

print('----------------')

print('Count of unique values in Credits Dataset')
for col in credits.columns:
  count = credits[col].nunique()
  print(f'{col} : {count}')
# Out:
# Count of unique values in Titles Dataset--------
# id : 9868
# title : 9737
# type : 2
# description : 9734
# release_year : 110
# age_certification : 11
# runtime : 207
# genres : 2028
# production_countries : 497
# seasons : 32
# imdb_id : 9201
# imdb_score : 86
# imdb_votes : 3650
# tmdb_popularity : 5325
# tmdb_score : 89
# ----------------
# Count of unique values in Credits Dataset
# person_id : 80508
# id : 8861
# name : 79758
# character : 71097
# role : 2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Remove Duplicate
#Titles
titles.drop_duplicates(inplace=True)

# %%
# Credits
credits.drop_duplicates(inplace=True)

# %%
print('Duplicate Count after processing')
print(f'Duplicate count in Titles Dataset: {titles.duplicated().sum()}')
print('-----------')
print(f'Duplicate count in Credits Dataset: {credits.duplicated().sum()}')
# Out:
# Duplicate Count after processing
# Duplicate count in Titles Dataset: 0
# -----------
# Duplicate count in Credits Dataset: 0

# %% [markdown]
# Drop columns with 70% or more null values

# %%
#Checking % of null values for each column

TitlesLen = titles.shape[0]
for col in titles.columns:
  null_count = titles[col].isnull().sum()
  print(f'% null values in {col} : {(null_count * 100 / TitlesLen):.2f}%')
# Out:
# % null values in id : 0.00%
# % null values in title : 0.00%
# % null values in type : 0.00%
# % null values in description : 1.21%
# % null values in release_year : 0.00%
# % null values in age_certification : 65.71%
# % null values in runtime : 0.00%
# % null values in genres : 0.00%
# % null values in production_countries : 0.00%
# % null values in seasons : 86.25%
# % null values in imdb_id : 6.76%
# % null values in imdb_score : 10.35%
# % null values in imdb_votes : 10.45%
# % null values in tmdb_popularity : 5.54%
# % null values in tmdb_score : 21.08%

# %%
#We can see that seasons column has more than 70% null values
#So we will drop these columns

try:
  titles = titles.drop(columns = ['seasons'])
except Exception as e:
  print(f'Error dropping columns')

# %%
#Remaining columns after dropping seasons
titles.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
#Check Null values in other columns for insights
titles[titles['description'].isnull() & titles['imdb_score'].isnull() & titles['imdb_votes'].isnull() & titles['tmdb_popularity'].isnull() & titles['tmdb_score'].isnull()]
# Out:
#              id                                         title   type  \
# 672    tm582037                                  Ye Shang Hai  MOVIE
# 1661   tm544335                                   Dhonni Meye  MOVIE
# 1804   tm526015                              Veera Thirumagan  MOVIE
# 1807   tm682750                                     Ram Joshi  MOVIE
# 3910  tm1060920          Yakov Smirnoff: Jokes from the Folks  MOVIE
# ...         ...                                           ...    ...
# 9781  tm1056635                       Rick Overton's Set List  MOVIE
# 9794  tm1084026                Leighann Lord: I Mean Business  MOVIE
# 9800   ts344471                                      Day Ones   SHOW
# 9816  tm1060910  Erik Terrell: Live at the Helium Comedy Club  MOVIE
# 9827  tm1099582                                      Hero 115  MOVIE
#
#      description  release_year age_certification  runtime      genres  \
# ...

# %%
#Since we can see that there are 69 rows with all null column values
# We can drop these rows as well

rowIndex = list(titles[titles['description'].isnull() & titles['imdb_score'].isnull() & titles['imdb_votes'].isnull() & titles['tmdb_popularity'].isnull() & titles['tmdb_score'].isnull()].index)
titles = titles.drop(index= rowIndex)

# %% [markdown]
# ###**Cleaning of Columns:**

# %% [markdown]
# #### Clean Description Column

# %%
#Since we cannot use any statistical method to fill null values for description column, we will instead fill it with 'Unknown'
#This will help us to keep track for further processing and analysis

titles['description'] = titles['description'].fillna('Unknown')

# %%
titles['description'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Clean Age-Certification Column

# %%
# We will fill the null values with 'Unknown'
# The remaining values will give us insights to analyse this column
# Cleaning any leading/trailig whitespaces as well

titles['age_certification'] = titles['age_certification'].fillna('Unknown').str.strip()

# %%
titles['age_certification'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Clean Imdb-ID Column

# %%
# We will fill the null values with 'Unknown'
# Cleaning any leading/trailig whitespaces as well

titles['imdb_id'] = titles['imdb_id'].fillna('Unknown').str.strip()

# %%
titles['imdb_id'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Clean imdb score

# %%
#Check DataType of the imdb column to use appropriate statistical model
titles['imdb_score'].dtype
# Out:
# dtype('float64')

# %%
#Check the skewness of the column
titles['imdb_score'].skew()
# Out:
# np.float64(-0.3595900258306863)

# %%
#The column data is normally skewed, visualizing this through a histogram
plt.title('Visualization of imdb_score (includes Null)')
sns.histplot(data = titles, x = 'imdb_score', kde = True)
# Out:
# <Axes: title={'center': 'Visualization of imdb_score (includes Null)'}, xlabel='imdb_score', ylabel='Count'>

# %%
titles["type"].head()
# Out:
# 0     SHOW
# 1    MOVIE
# 2    MOVIE
# 3    MOVIE
# 4    MOVIE
# Name: type, dtype: object

# %%
#Using mean on groupby 'type' column to fill null values
titles['imdb_score'] = titles['imdb_score'].fillna(titles.groupby('type')['imdb_score'].transform('mean'))

# %%
#Rounding the mean values to 2 decimal places
titles['imdb_score'] = titles['imdb_score'].apply(lambda x: round(x,2))

# %%
titles['imdb_score'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Clean imdb_votes

# %%
#Check column datatype
titles['imdb_votes'].dtype
# Out:
# dtype('float64')

# %%
#Check column skewness
titles['imdb_votes'].skew()
# Out:
# np.float64(12.515552053924822)

# %%
#visualizing the skewness of imdb votes column through histogram plot
titles['imdb_votes'].plot(kind='hist')
plt.title('Visualization of imdb_votes (includes Null)')
plt.xlabel('imdb_votes')
plt.ylabel('Frequency')
plt.show()

# %%
#visualizing the skewness of imdb votes column through kde plot
titles['imdb_votes'].plot(kind='kde')
plt.title('Visualization of imdb_votes (includes Null)')
plt.xlabel('imdb_votes')
plt.ylabel('Frequency')
plt.show()

# %%
#Column is positively skewed, so we fill the values with median
titles['imdb_votes'] = titles['imdb_votes'].fillna(titles.groupby('type')['imdb_votes'].transform('median'))

# %%
titles['imdb_votes'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Since votes cannot be in fraction, we will convert this column datatype to int
titles['imdb_votes'] = titles['imdb_votes'].astype(int)

# %% [markdown]
# #### Clean tmdb_popularity

# %%
titles['tmdb_popularity'].dtype
# Out:
# dtype('float64')

# %%
#Check column skewness
titles['tmdb_popularity'].skew()
# Out:
# np.float64(26.77120679871341)

# %%
#The column values are right skewed by a large margin
#Visualising it through a histplot
titles['tmdb_popularity'].plot(kind='hist')
plt.title('Visualization of tmdb_popularity (includes Null)')
plt.xlabel('tmdb_popularity')
plt.ylabel('Frequency')
plt.show()

# %%
#Visualising it through a kde plot
titles['tmdb_popularity'].plot(kind='kde')
plt.title('Visualization of tmdb_popularity (includes Null)')
plt.xlabel('tmdb_popularity')
plt.ylabel('Frequency')
plt.show()

# %%
#Column is positively skewed, so we fill the values with median
titles['tmdb_popularity'] = titles['tmdb_popularity'].fillna(titles.groupby('type')['tmdb_popularity'].transform('median'))

# %%
#After cleaning null values
print(titles['tmdb_popularity'].isnull().sum())
# Out:
# 0

# %% [markdown]
# #### Clean tmdb_score

# %%
titles['tmdb_score'].dtype
# Out:
# dtype('float64')

# %%
#check column skewness
titles['tmdb_score'].skew()
# Out:
# np.float64(-0.33482152530934456)

# %%
#Visualising skewness through histplot
plt.title("Visualising tmdb_score (Includes Null)")
sns.histplot(data = titles, x ='tmdb_score', kde = True)
# Out:
# <Axes: title={'center': 'Visualising tmdb_score (Includes Null)'}, xlabel='tmdb_score', ylabel='Count'>

# %%
#Tmdb_score is normally skewed so we replace the null values with mean based on type
titles['tmdb_score'] = titles['tmdb_score'].fillna(titles.groupby('type')['tmdb_score'].transform('mean'))

# %%
titles['tmdb_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9799 entries, 0 to 9870
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9799 non-null   object
#  1   title                 9799 non-null   object
#  2   type                  9799 non-null   object
#  3   description           9799 non-null   object
#  4   release_year          9799 non-null   int64
#  5   age_certification     9799 non-null   object
#  6   runtime               9799 non-null   int64
#  7   genres                9799 non-null   object
#  8   production_countries  9799 non-null   object
#  9   imdb_id               9799 non-null   object
#  10  imdb_score            9799 non-null   float64
#  11  imdb_votes            9799 non-null   int64
#  12  tmdb_popularity       9799 non-null   float64
#  13  tmdb_score            9799 non-null   float64
# dtypes: float64(3), int64(3), object(8)
# ...

# %% [markdown]
# ### Preprocess Credits Dataset

# %% [markdown]
# ### Clean Character Column

# %%
credits.isnull().sum()
# Out:
# person_id        0
# id               0
# name             0
# character    16277
# role             0
# dtype: int64

# %%
# Filling the null character values with Unknown
credits['character'] = credits['character'].fillna('Unknown')

# %%
titles.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
credits.isnull().sum()
# Out:
# person_id    0
# id           0
# name         0
# character    0
# role         0
# dtype: int64

# %% [markdown]
# ### Merging Titles and Credits Dataset on common 'id' column

# %%
titles.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1           Unknown       78
# 2           Unknown      171
# 3           Unknown       92
# 4           Unknown       94
#
#                                               genres production_countries  \
# ...

# %%
credits.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
#Now that both the dataset is clean, we can merge them on common 'id' column for final analysis and visualization
#We will merge on Left Outer Join, keeping all the values from titles dataset and matching values from credits dataset

ct_dataset = pd.merge(titles, credits, how = 'left', on = 'id')

# %%
ct_dataset.shape
# Out:
# (125117, 18)

# %%
#First look of merged dataset

ct_dataset.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3           Unknown       78
# 4           Unknown       78
#
#                                               genres production_countries  \
# ...

# %%
# Checking for any null values after merging
ct_dataset.isnull().sum()
# Out:
# id                        0
# title                     0
# type                      0
# description               0
# release_year              0
# age_certification         0
# runtime                   0
# genres                    0
# production_countries      0
# imdb_id                   0
# imdb_score                0
# imdb_votes                0
# tmdb_popularity           0
# tmdb_score                0
# person_id               938
# name                    938
# character               938
# role                    938
# dtype: int64

# %%
# First look at the null data

ct_dataset[ct_dataset['person_id'].isnull() & ct_dataset['name'].isnull() & ct_dataset['character'].isnull() & ct_dataset['role'].isnull()]
# Out:
#                id                         title   type  \
# 2063     tm348419         Payoff in the Pacific  MOVIE
# 7531      tm18966  D-Day: The Normandy Invasion  MOVIE
# 13109    tm686160                 Peculiar Pets  MOVIE
# 14043    tm769632                     Sri Valli  MOVIE
# 14122    tm808043                  Death Valley  MOVIE
# ...           ...                           ...    ...
# 125051  tm1084430           Parigettu Parigettu  MOVIE
# 125079  tm1090675      Burning Man: The Musical  MOVIE
# 125080  tm1142918               Ty Barnett: Yep  MOVIE
# 125097   ts295958                 GameOn Titans   SHOW
# 125116   ts275838              Waking Up Eighty   SHOW
#
#                                               description  release_year  \
# 2063    A documentary on .S. efforts against the Japan...          1945
# 7531    Focusing on both the strategic overview of the...          1945
# 13109   In this documentary, we meet the families whom...          1921
# ...

# %%
# From this data we can figure out that several other columns have values such as 'Unknown' or mean / median processed values
# Narrowing the data based on these metrics to possibly drop from the table
temp = ct_dataset[ct_dataset['person_id'].isnull() & ct_dataset['name'].isnull() & ct_dataset['character'].isnull() & ct_dataset['role'].isnull()]
temp[(temp['age_certification'] == 'Unknown')]
# Out:
#                id                         title   type  \
# 2063     tm348419         Payoff in the Pacific  MOVIE
# 7531      tm18966  D-Day: The Normandy Invasion  MOVIE
# 13109    tm686160                 Peculiar Pets  MOVIE
# 14043    tm769632                     Sri Valli  MOVIE
# 14122    tm808043                  Death Valley  MOVIE
# ...           ...                           ...    ...
# 125050  tm1076901          Jaan! Jaan Loge Kya?  MOVIE
# 125051  tm1084430           Parigettu Parigettu  MOVIE
# 125079  tm1090675      Burning Man: The Musical  MOVIE
# 125097   ts295958                 GameOn Titans   SHOW
# 125116   ts275838              Waking Up Eighty   SHOW
#
#                                               description  release_year  \
# 2063    A documentary on .S. efforts against the Japan...          1945
# 7531    Focusing on both the strategic overview of the...          1945
# 13109   In this documentary, we meet the families whom...          1921
# ...

# %%
# Checking if there are any duplicate values in the merged dataset

ct_dataset.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Removing rows where most values are NAN and other columns are 'Unknown'
rows = temp[(temp['age_certification'] == 'Unknown')].index
ct_dataset.drop(index = rows, inplace = True)

# %% [markdown]
# ### Filling Null values in merged dataset with 'Unknown' since these are categorical data

# %%
# Final processing
# Applying directly to all the null column values

df = ct_dataset.fillna('Unknown')

# %%
# Last check for any null values
df.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %%
df
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125111  tm1054116           Baikunth  MOVIE
# 125112  tm1054116           Baikunth  MOVIE
# 125113  tm1054116           Baikunth  MOVIE
# 125114  tm1054116           Baikunth  MOVIE
# 125115  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# **Checking Outliers**

# %%
df.select_dtypes(include='number').boxplot(figsize=(12, 6))
plt.xticks(rotation=45)
plt.show()

# %%
num_cols = df.select_dtypes(include='number').columns

for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col])
    plt.title(col)
    plt.show()

# %%
#checking for runtime greater than 200 min
runtime_200=df[df['runtime']<200]
runtime_200
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125111  tm1054116           Baikunth  MOVIE
# 125112  tm1054116           Baikunth  MOVIE
# 125113  tm1054116           Baikunth  MOVIE
# 125114  tm1054116           Baikunth  MOVIE
# 125115  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %%
#removing values which has runtime greater than 200 min
df = df[df['runtime'] <=200]

# %%
#checking if there is any negative or beyond 10 imdb score
df[(df['imdb_score'] < 1) & (df['imdb_votes'] > 10)]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
#checking if there is any negative or beyond 10 tmdb score
df[(df['tmdb_score'] < 1) & (df['tmdb_popularity'] > 10)]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score, person_id, name, character, role]
# Index: []

# %%
df.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3           Unknown       78
# 4           Unknown       78
#
#                                               genres production_countries  \
# ...

# %%
# importing ast(abstract syntax tree)
# using ast.literal() function since it safely converts a string representation of python list
import ast

def safe_eval(x):
    if isinstance(x, str):
        try:
            return ast.literal_eval(x)
        except:
            return []
    return x

for col in ['genres', 'production_countries']:
    df[col] = df[col].apply(safe_eval)
# Out:
# /tmp/ipykernel_6818/2870296867.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].apply(safe_eval)

# %%
df
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 125111  tm1054116           Baikunth  MOVIE
# 125112  tm1054116           Baikunth  MOVIE
# 125113  tm1054116           Baikunth  MOVIE
# 125114  tm1054116           Baikunth  MOVIE
# 125115  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **Data Manipulations Performed**
#
# To ensure the dataset was ready for analysis, several data cleaning and transformation steps were performed:
#
# **Merging Datasets**
#
# Combined the titles dataset (titles.csv) and credits dataset (credits.csv) on the common key (id).
#
# Resulted in a consolidated dataframe (df) containing both title-level metadata and cast/crew details.
#
# **Handling Missing Values**
#
# Removed duplicate entries.
#
# Imputed or dropped missing values for fields like description, runtime, age certification, and ratings (imdb_score, tmdb_score).
#
# **Outlier Treatment**
#
# Identified and removed outliers in runtime, ratings, and popularity scores.
#
# **Data Standardization**
#
# Normalized categorical variables like genres, production countries.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# **Univariate Analysis**
# #### Chart - 1 Pie Chart
# ***How content type is distributed in the dataframe***

# %%
# Remove duplicate movies/shows based on id
df_unique = df.drop_duplicates(subset='id')

# Count Movies and TV Shows released each year
yearly_counts = (
    df_unique
    .groupby(['release_year', 'type'])
    .size()
    .reset_index(name='count')
)

# %%
yearly_counts.head()
# Out:
#    release_year   type  count
# 0          1912  MOVIE      1
# 1          1914  MOVIE      2
# 2          1915  MOVIE      5
# 3          1916  MOVIE      2
# 4          1917  MOVIE      1

# %%
# Chart - 1 visualization code
yearly_counts['type'].value_counts().plot(kind='pie', autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Shows proportions clearly**– A pie chart highlights what percentage of the total each category represents.
#
# **Best for categorical data** – The type column contains categories rather than numerical values, making a pie chart suitable for visualizing category distribution.
#
# **Easy to identify the dominant category** – You can quickly see which type occupies the largest share of the dataset

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# - The dataset is dominated by the **Movies(70%)**.
# - **30%** of TV Shows.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Shows content distribution** – Movies dominate the catalog, making up 70.1% of all titles.
#
# **Highlights growth opportunities** – The low number of TV Shows suggests a category that could be expanded.
#
# **Can improve user retention** – More TV Shows may keep viewers engaged for longer periods.
#
# **Aids competitive analysis** – Helps compare the platform's content mix with competitors and identify gaps.

# %% [markdown]
# #### Chart - 2 Line Chart
# ***How has the release trend of Movies and TV Shows on Amazon Prime Video changed over the years?***

# %%
# Remove duplicate movies/shows based on id
df_unique = df.drop_duplicates(subset='id')

# Count Movies and TV Shows released each year
yearly_counts = (
    df_unique
    .groupby(['release_year', 'type'])
    .size()
    .reset_index(name='count')
)

# Convert to wide format for plotting
plot_data = yearly_counts.pivot(
    index='release_year',
    columns='type',
    values='count'
).fillna(0)

# Plot

plt.figure(figsize=(12,6))

for col in plot_data.columns:
    plt.plot(
        plot_data.index,
        plot_data[col],
        marker='o',
        label=col
    )

plt.title('Movies and TV Shows Released Over Time')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.legend()
plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Shows trends clearly**
# Helps identify whether values are increasing, decreasing, or staying stable over time.
#
# **Best for ordered data**
# Works well when the x-axis has a meaningful sequence (e.g., release years from 1920 to 2025).
#
# **Reveals patterns**
# You can easily spot peaks, dips, cycles, and growth periods.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
#  **Movies dominate the platform throughout the timeline**
#
# Movie releases are consistently much higher than TV Show releases.
#
# In recent years, movie counts are several times larger than TV Show counts
#
# **Strong growth in content production after the 2010s**
#
# Both Movies and TV Shows show a sharp increase from around 2015 onward.
#
# The growth is especially steep for Movies.
#
# **TV Shows are growing faster than before**
#
# Although TV Shows remain fewer, their growth rate accelerates significantly in recent years.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Optimize Content Investment**: Since movies generate the majority of the catalog, the company can allocate acquisition and production budgets more effectively toward high-demand movie content.
#
# **Expand Successful Content Strategy**: The strong growth in releases after 2015 indicates successful platform expansion, encouraging further investment in content partnerships and production.
#
# **Increase Subscriber Retention**: The rising number of TV Shows suggests growing audience interest in episodic content, creating opportunities to improve user engagement and reduce churn

# %% [markdown]
# #### Chart - 3
# ***Understanding Content Through Age Certifications***

# %%
# Only unique id taken into consideration
df_unique['age_certification'].value_counts().plot(kind='bar')
plt.xlabel('Age Certification')
plt.ylabel('Count')
plt.title('Distribution of Age Certification')
# Out:
# Text(0.5, 1.0, 'Distribution of Age Certification')

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Categorical data visualization** – age_certification contains categories (e.g., G, PG, PG-13, R), and bar charts are ideal for comparing category frequencies.
#
# **Easy comparison** – The height of bars makes it simple to compare which certification levels have more or fewer titles.
#
# **Shows distribution clearly** – Helps identify how content is distributed across different age groups.
#
# **Highlights dominant categories** – Quickly reveals the most common age certification in the dataset.
#
# **Works well with many categories** – Unlike pie charts, bar charts remain readable even when there are several certification levels.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# **'Unknown' dominates the dataset** with a very large number of titles compared to all other certification categories.
#
# **'R' rated content is the most common known certification**, indicating a strong presence of mature/audience-targeted content.
#
# '**PG-13' and 'PG' categories have similar counts**, suggesting a balanced supply of family-friendly and teen-oriented content.
#
# **Children-focused certifications ('G', 'TV-Y', 'TV-Y7')** are relatively scarce, showing limited content aimed at young viewers.
#
# **Higher TV-specific ratings ('TV-MA', 'TV-14') are more common** than children's TV ratings, indicating greater focus on older audiences.
#
# **Some certification categories (e.g., NC-17, TV-G, TV-Y7)** have very few titles, making them niche segments in the dataset

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Improve data quality** by reducing the large number of "Unknown" certifications, leading to more accurate audience analysis and recommendations.
#
# **Prioritize investment in popular categories** such as R, PG-13, and PG content to maximize audience engagement and revenue.
#
# **Identify underserved markets**, such as children's content, and create new offerings to attract families and younger viewers

# %% [markdown]
# #### Chart - 4
# ***Content Classification by Genre distribution***

# %%
#first exploding the Genre Column
dfx = df.explode('genres').reset_index(drop=True)
dfx
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         ts20945  The Three Stooges   SHOW
# 4         ts20945  The Three Stooges   SHOW
# ...           ...                ...    ...
# 318945  tm1054116           Baikunth  MOVIE
# 318946  tm1054116           Baikunth  MOVIE
# 318947  tm1054116           Baikunth  MOVIE
# 318948  tm1054116           Baikunth  MOVIE
# 318949  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       The Three Stooges were an American vaudeville ...          1934
# ...

# %%
#plotting the bar graph for Genre
dfx['genres'].value_counts().plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Distribution of Genre')
# Out:
# Text(0.5, 1.0, 'Distribution of Genre')

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Categorical data visualization** –   bar charts are ideal for comparing different genres frequencies.
#
# **Easy comparison** – The height of bars makes it simple to compare which genre have more or fewer titles.
#
# **Shows distribution clearly** – Helps identify how content is distributed across different genres.
#
# **Highlights dominant genres** – Quickly reveals the most common genres in the dataset.
#
# **Works well with many categories** – Unlike pie charts, bar charts remain readable even when there are several genres categories.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# **Drama is the most dominant genre** by a very large margin, with nearly 69,000 titles.
#
# **Comedy is the second most popular genre**, but it has significantly fewer titles than Drama.
#
# **Thriller, Action, and Romance** form the next major content categories, indicating strong audience demand for entertainment-focused genres.
#
# There is a **sharp drop after the top 5–6 genres**, showing that content is concentrated in a few dominant genres.
#
# The distribution is **highly imbalanced**, meaning some genres receive much more production and distribution attention than others

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Invest more in Drama and Comedy content** since they represent the largest share of the catalog and likely attract the widest audience.
#
# **Optimize marketing budgets** by focusing promotional campaigns on the top-performing genres.
#
# **Identify content gaps** in underrepresented genres like Animation, Sport, and Reality to attract new audience segments.
#
# **Discover growth opportunities** by expanding genres with moderate popularity (Sci-Fi, Fantasy, Horror) that have potential for future demand growth.

# %% [markdown]
# #### Chart - 5
# ***What is the distribution of content production countries on Amazon Prime Video?***

# %%
# First exploding the country column
dfy = df.explode('production_countries').reset_index(drop=True)
dfy
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 146769  tm1054116           Baikunth  MOVIE
# 146770  tm1054116           Baikunth  MOVIE
# 146771  tm1054116           Baikunth  MOVIE
# 146772  tm1054116           Baikunth  MOVIE
# 146773  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %%
#dropping the duplicate ids after exploding the column
df_unique_ = dfy.drop_duplicates(subset='id')
#plotting the bar graph
df_unique_['production_countries'].value_counts().head(10).plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Distribution of Country')
# Out:
# Text(0.5, 1.0, 'Distribution of Country')

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Categorical data visualization** –   bar charts are ideal for comparing different countries contribution to the dataset.
#
# **Easy comparison** – The height of bars makes it simple to compare which country have more or fewer titles.
#
# **Shows distribution clearly** – Helps identify how content is distributed across different countries.
#
# **Highlights dominant country** – Quickly reveals the most common country in the dataset.
#
# **Works well with many categories** – Unlike pie charts, bar charts remain readable even when there are several countries.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# **United States (US) dominates the dataset**, contributing a significantly higher number of titles than any other country.
#
# **India (IN) is the second-largest contributor**, but its count is far below that of the US.
#
# **United Kingdom (GB) ranks third**, showing a notable presence in the content library.
#
# **Canada (CA) contributes a moderate number of titles**, indicating a smaller but meaningful share.
#
# **Countries such as France (FR), Australia (AU), China (CN), Italy (IT), and Germany (DE)** have relatively low representation

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Strengthen partnerships with top-producing countries** to secure a steady pipeline of popular content.
#
# **Identify underrepresented countries as growth opportunities** for expanding the content catalog and reaching new audiences.
#
# **Improve content localization strategies** by understanding which regions contribute most to the platform.
#
# **Reduce overdependence on a few countries** by diversifying content acquisition across more regions.

# %% [markdown]
# **Negative Impact**
#
# **Overdependence on US-produced content** is the biggest concern. If audience preferences shift, licensing costs rise, or competition intensifies in the US market, the business could face significant challenges because much of its content portfolio is concentrated in one region

# %% [markdown]
# **Bivariate Analysis**
# #### Chart - 6
# ***Audience Engagement Trend: Average IMDb Votes Over Time***

# %%
#only unique movie/show id
df_unique_=df.drop_duplicates(subset='id')
# Calculate average votes per year
votes_per_year = df_unique_.groupby(['release_year', 'type'], as_index='False')['imdb_votes'].mean().reset_index()
votes_per_year
# line plot
fig = px.line(
    votes_per_year,
    x='release_year',
    y='imdb_votes',
    color='type',
    markers=True,
    title='Avg IMDb Votes per Release Year',
    labels={
        'release_year': 'Release Year',
        'imdb_votes': 'IMDb Votes'
    }
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# *   A line chart is ideal for showing trends over time because Release Year is a time-based variable.
# *  It makes it easy to observe increases, decreases, and long-term patterns in average IMDb votes.
#
# *   Multiple categories (Movies and TV Shows) can be compared on the same graph using separate lines.
# *   Peaks and dips are clearly visible, helping identify years with unusually high or low audience engagement.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# Movies have a more consistent trend over time, but several years (especially around the late 1990s and early 2000s) contain exceptionally popular titles with very high vote counts
#
# TV Shows show very high vote spikes after the late 1990s and especially during the 2000s–2010s, suggesting strong viewer interest in serialized content.
#
# The period from roughly 1995–2015 appears to contain the highest audience engagement for both Movies and TV Shows

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Focus marketing budgets on content formats (Movies or TV Shows) that historically generate higher audience engagement.
#
# Invest more in high-quality TV Show production since recent years show strong audience interest and voting activity.
#
# Use highly rated and highly voted titles to attract new subscribers through recommendations and promotions

# %% [markdown]
# #### Chart - 7
# ***Trends in IMDb: Average Votes, Ratings, and Title Volume Across Release Years***

# %%
# Keep only unique titles
df_unique = df.drop_duplicates(subset='id')

# Calculate overall averages
avg_votes = df_unique['imdb_votes'].mean()
avg_score = df_unique['imdb_score'].mean()

# Filter titles having both above-average votes and score
top_titles = df_unique[
    (df_unique['imdb_votes'] > avg_votes) &
    (df_unique['imdb_score'] > avg_score)
]

# Count by year and type
yearly_count = (
    top_titles
    .groupby(['release_year', 'type'])['id']
    .nunique()
    .reset_index(name='count')
)

# Plot
fig = px.line(
    yearly_count,
    x='release_year',
    y='count',
    color='type',
    markers=True,
    title='Count of Titles with Above-Average IMDb Votes & Score by Year'
)

fig.update_layout(
    xaxis_title='Release Year',
    yaxis_title='Number of Titles',
    hovermode='x unified'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# *   A line chart is ideal for showing trends over time because Release Year is a time-based variable.
# *  It makes it easy to observe increases, decreases, and long-term patterns in average IMDb votes.
#
# *   Multiple categories (Movies and TV Shows) can be compared on the same graph using separate lines.
# *   Peaks and dips are clearly visible, helping identify years with unusually high or low audience engagement.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# *   The number of movies with above-average IMDb votes and scores increases significantly after the 2000s.
#
# *   Growth becomes especially steep between 2010 and 2022.
#
# *   Before 2010, very few TV shows meet both criteria.
#
# *   From 2010 onward, the count rises noticeably, peaking around 2019–2020.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Since movies generate more high-performing titles, budgets can be allocated efficiently toward movie production while maintaining selective TV show investments.
# *   Rising success of TV shows after 2010 supports increased investment in episodic and binge-worthy content.
#
# *   Helps improve subscriber retention

# %% [markdown]
# #### Chart - 8
# ***Runtime vs IMDb Votes: Understanding Viewer Engagement Across Movie Lengths***

# %%
fig = px.scatter(
    df_unique,
    x='runtime',
    y='imdb_votes',
    color='type',
    hover_data=['title'],
    title='Runtime vs IMDb Votes'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(
    df_unique,
    x='runtime',
    y='imdb_score',
    color='type',
    hover_data=['title'],
    title='Runtime vs IMDb score'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Shows relationship between two numerical variables**
#
# Runtime, IMDb Votes, and IMDb Score are all numeric values, making scatter plots a natural choice.
#
# **Helps identify correlation**
#
# You can quickly see whether longer movies tend to receive more votes or higher ratings.
#
# **Shows data density**
#
# Areas with many overlapping points indicate common runtime ranges and popularity levels.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# *   Movies (80–150 minutes) dominate the dataset and attract the highest number of votes and score.
# *   Most movies are concentrated between 80–120 minutes with IMDb scores between 5 and 7.
#
# *   TV Shows tend to cluster between ratings of 7–8.5, suggesting generally stronger audience satisfaction.
# *   The majority of content falls within the average rating range (5–7).

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Focus marketing budgets on high-potential movies in the 90–130 minute range, where most highly voted titles appear.
# *   TV Shows can be produced with shorter runtimes while still maintaining audience engagement, reducing production costs
#
# *   Shorter, well-produced content can achieve ratings comparable to longer productions
# *   TV Shows appear to have strong audience satisfaction, supporting further investment in episodic content.

# %% [markdown]
# #### Chart - 9
# ***IMDb Audience Engagement Across Genres (Average Votes)***

# %%
# Average IMDb votes by genre
genre_votes = (
    dfx.groupby('genres')['imdb_votes'].mean()
    .sort_values(ascending=False)
    .reset_index()
)

# Plot
fig = px.bar(
    genre_votes,
    x='genres',
    y='imdb_votes',
    title='Average IMDb Votes by Genre',
    labels={'genres': 'Genre', 'imdb_votes': 'Average IMDb Votes'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
genre_votes
# Out:
#            genres    imdb_votes
# 0           scifi  57775.808869
# 1             war  43572.967793
# 2         fantasy  41520.009082
# 3        thriller  36260.233212
# 4          action  34904.351223
# 5         history  34898.782841
# 6        european  33125.524469
# 7         romance  27786.149190
# 8           crime  24638.061634
# 9           drama  23492.186225
# 10          sport  22643.245035
# 11         family  19581.985660
# 12         comedy  19208.188651
# 13      animation  18944.755075
# 14         horror  15047.316274
# 15          music   9007.659730
# 16  documentation   6943.215342
# 17        western   3808.394783
# 18        reality   2245.052500

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Categorical data visualization** – Genre contains categories (e.g., scifi, fantasy, thriller etc.), and bar charts are ideal for comparing category frequencies.
#
# **Easy comparison** – The height of bars makes it simple to compare which genre have more or fewer aundience.
#
# **Shows distribution clearly** – Helps identify how content is distributed across different genres.
#
# **Highlights dominant categories** – Quickly reveals the most engaging genre category in the dataset.
#
# **Works well with many categories** – Unlike pie charts, bar charts remain readable even when there are several genre categories.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# *   Sci-Fi has the highest average IMDb votes (~24K), significantly higher than all other genres.
#
# *   War is the second most popular genre based on audience engagement (~19K votes).
# *   Fantasy ranks third, showing strong viewer interest and discussion.
#
# *   There is a large gap between the top 3 genres (Sci-Fi, Fantasy, Thriller) and the remaining genres, indicating stronger audience engagement in these categories.
# *  Niche genres such as Sport, Music, and Documentary may have dedicated audiences but attract fewer overall votes.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Higher investment in Sci-Fi, Fantasy, and Thriller content may generate greater audience engagement and visibility.
# *   Streaming platforms can use these insights to improve recommendation systems and increase watch time.
#
# *   Viewer engagement metrics can help prioritize content for featured sections and homepage recommendations.

# %% [markdown]
# Possible **Negative Impact**
#
# *   Over-investing in top-performing genres could lead to market saturation and audience fatigue.
# *   Ignoring low-vote genres may cause businesses to miss profitable niche markets with loyal fan base.

# %% [markdown]
# #### Chart - 10
# ***Top performing Titles in the dataset***

# %%
top_titles = (
    df_unique[df_unique['imdb_votes'] >= df_unique['imdb_votes'].quantile(0.75)]
      .sort_values(
          ['imdb_score', 'imdb_votes'],
          ascending=[False, False]
      )
)

top_titles[['title', 'imdb_score', 'imdb_votes']].head(20)
# Top 20 titles
top20 = top_titles[['title', 'imdb_score', 'imdb_votes']].head(20)

fig = px.bar(
    top20.sort_values('imdb_score'),
    x='imdb_score',
    y='title',
    orientation='h',
    title='Top 20 Performing Titles by IMDb Score',
    hover_data=['imdb_votes'],
    labels={
        'imdb_score': 'IMDb Score',
        'title': 'Title'
    }
)

fig.update_layout(
    height=700,
    yaxis={'categoryorder': 'total ascending'}
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Easy Ranking Comparison**
#
# A bar chart makes it easy to compare IMDb scores across titles and immediately identify the highest and lowest performers.
#
# **Best for Categorical Data**
#
# Movie/show titles are categorical variables, and bar charts are one of the most effective visualizations for comparing categories.
#
# **Handles Long Movie Titles Well**
#
# Horizontal bars provide more space for title names, preventing label overlap and improving readability.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# *   The titles with the highest ratings and strongest audience engagement identified.
# *   Titles with both high scores and high vote counts are likely the most widely successful and trusted by audiences.
#
# *   The graph helps identify potential "benchmark" titles that represent the highest-performing content.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Supports investment decisions by highlighting patterns among top-performing content
# *   Assists recommendation systems in promoting proven audience favorites
#
# *   Helps streaming platforms prioritize licensing or marketing efforts for high-demand titles.

# %% [markdown]
# #### Chart - 11
# ***Top performing Actors***

# %%
top_actors = (
    df.groupby('name')
             .agg(
                 avg_imdb_score=('imdb_score', 'mean'),
                 total_votes=('imdb_votes', 'sum'),
                 title_count=('title', 'count')
             )
             .query('title_count >= 3')
             .sort_values('total_votes', ascending=False)
)
top_actors.head(10).reset_index()

top10_actors = top_actors.head(10).reset_index()
fig = px.bar(
    top10_actors,
    x='total_votes',
    y='name',
    orientation='h',
    text='title_count',
    hover_data={
        'name': True,
        'total_votes': ':,',
        'title_count': True,
        'avg_imdb_score': ':.2f'
    },
    title='Top 10 Actors by Total IMDb Votes'
)

fig.update_traces(
    texttemplate='%{text} titles',
    textposition='outside'
)

fig.update_layout(
    xaxis_title='Total IMDb Votes',
    yaxis_title='Actor Name',
    yaxis={'categoryorder': 'total ascending'},
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Easy comparison of actors**
#
# Bar charts are one of the best ways to compare values across categories (actors in this case). You can quickly see which actors have received the most IMDb votes.
#
# **Clearly shows rankings**
#
# Since the data is sorted by total IMDb votes, the chart naturally displays a ranking from most popular to least popular among the top actors.
#
# **Additional metrics can be displayed without clutter**
#
# Number of titles and average IMDb score can be shown through labels and hover tooltips, giving extra context while keeping the chart clean and easy to understand.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# James Cameron dominates audience popularity
#
# **Quality can outperform quantity**
#
# **Peter Stormare** appears in 17 titles, the highest title count among the top 10.
#
# However, his total votes are significantly lower than James Cameron's 3 titles.
#
# More projects do not necessarily result in higher audience engagement.
#
# **Mel Gibson shows strong consistency**
#
# With 10 titles and nearly 3 million votes, Mel Gibson combines both volume and popularity.
#
# This indicates a strong and consistent track record with audiences.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Better casting decisions**
#
# Producers can identify actors/directors associated with high audience engagement.
#
# **Stronger marketing campaigns**
#
# Popular names can be highlighted in trailers, posters, and promotions.
#
# **Better content acquisition decisions**
#
# Streaming platforms can use this analysis when purchasing movie rights.
#
# Titles featuring highly voted actors may attract more viewers and subscriptions.

# %% [markdown]
# **Important Observation**
#
# Total IMDb Votes measure popularity, not quality.
#
# An actor may have high votes because their movies reached large audiences

# %% [markdown]
# **Multivariate Analysis**
# #### Chart - 12 Correlation Heatmap
# ***Analyzing the correlation between runtime, imdb score, imdb votes and tmdb popularity***

# %%
# Select numerical columns
corr_matrix = df[['runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity']].corr()

# Create heatmap
fig = px.imshow(
    corr_matrix,
    text_auto='.2f',
    color_continuous_scale='RdBu_r',
    title='Correlation Heatmap'
)

fig.update_layout(
    width=700,
    height=600
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# **Shows correlations at a glance** –
#  A heatmap allows you to view the relationship between multiple variables simultaneously instead of comparing them one by one.
#
# **Identifies strong and weak relationships easily** –
#  Color intensity makes it easy to spot variables that are highly correlated or barely related.
#
#  **Saves space and improves readability** – Instead of several scatter plots, one heatmap summarizes all pairwise correlations in a single visualization.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
#  **IMDb Score and IMDb Votes have the strongest relationship**
# Correlation = 0.26
#
# Movies with higher IMDb scores tend to receive more votes.
#
# Although the relationship is positive, it is still relatively weak.
#
# **Runtime and IMDb Votes show a weak positive relationship**
# Correlation = 0.23
#
# Longer movies tend to receive slightly more votes.
#
# **TMDb Popularity and IMDb Votes are positively related**
#
# Correlation = 0.23
#
# Popular movies on TMDb generally receive more IMDb votes.
#
# **Runtime and IMDb Score have almost no relationship**
#
# Correlation = 0.09
#
# Longer movies are not necessarily rated better.
#
# **TMDb Popularity and IMDb Score have very weak correlation**
# Correlation = 0.08
#
# Popular movies are not always highly rated.
#
# **Runtime and TMDb Popularity have virtually no relationship**
# Correlation = 0.03
#
# Movie length has almost no impact on popularity.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Focus on content quality** because higher-rated movies tend to attract more audience engagement (more IMDb votes).
#
# **Use popularity metrics for marketing decisions**, as popular movies generally receive more audience attention.
#
# **Do not rely on runtime as a success factor**, since movie length has little impact on ratings or popularity.
#
# **Track ratings and popularity separately**, because highly popular movies are not always highly rated.
#
#
#
# **Audience engagement (IMDb votes) can serve as a useful performance indicator**, as it shows weak positive relationships with both ratings and popularity.
#
# **Optimize marketing and content strategy together**, since quality and visibility both contribute to attracting viewers.
#
# **Build predictive models using more features**, because the correlations are generally weak and no single metric strongly explains movie success

# %% [markdown]
# #### Chart - 13 Pair Plot
# ***How do IMDb Score, IMDb votes, TMDb Popularity, TMDb score interact across Movies and TV Shows on Amazon Prime Video?***

# %%
#selecting columns
pairplot_df=df[['imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']]
#plotting the graph
sns.pairplot(pairplot_df, diag_kind='kde')
plt.show()

# %% [markdown]
# ##### **1. Why did you pick the specific chart?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### **2. What is/are the insight(s) found from the chart?**

# %% [markdown]
# *   Quality (IMDb Score ↔ TMDb Score) shows strong positive alignment.
# *   Higher-rated movies generally attract more audience engagement (IMDb Votes).
#
# *   Popularity and quality are related but not strongly dependent.
# *   A small number of blockbuster titles dominate votes and popularity.
#
# *   High-rated but less popular titles represent potential growth opportunities through targeted marketing.

# %% [markdown]
# ##### **3. Will the gained insights help creating a positive business impact?**
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# *   Invest in high-rated content to increase audience satisfaction and retention.
# *   Use IMDb Votes and ratings to identify content with proven audience demand.
#
# *   Promote high-quality but less popular titles to unlock hidden growth opportunities.
# *   Improve recommendation systems by leveraging the strong alignment between IMDb and TMDb scores.
#
# *   Reduce acquisition risk by selecting content that consistently performs well across multiple rating platforms.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### **What do you suggest the client to achieve Business Objective ?**
# Explain Briefly.

# %% [markdown]
# **Final Insights**
#
# 1. Movies dominate over TV shows on Amazon Prime.
#
# 2. Scifi, War and Fantasy are the most popular genres.
#
# 3. U.S. and India lead in content production; other regions are underrepresented.
#
# 4. High IMDb/TMDB ratings strongly correlate with votes and popularity.
#
# 5. R, PG-13 and 16+ rated content prevails, showing focus on mature audiences.
#
# 6. Content with a runtime of 80-120 minutes(Movies) and 40-60 minutes(TV Shows) appears most aligned with viewer consumption patterns.
#
# ---
# **Business Recommendations:**
#
# **Focus on Top Genres** - Invest in Scifi, War and Fantasy for higher engagement.
#
# **Expand Globally** - Produce or acquire more regional content beyond U.S. and India.
#
# **Prioritize Quality** - Emphasize high-rated, high-impact titles over volume.
#
# **Personalized Experience** - Use viewer age and genre data for smarter recommendations.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of the Amazon Prime TV Shows and Movies dataset highlights key content trends and strategic opportunities for growth. The platform is dominated by U.S.-based movies, while expanding international content and increasing TV shows could enhance global reach and user retention. Genres such as SciFi, War, Fantasy and Thriller show strong representation, indicating high audience preference. Content with a runtime of 80-120 minutes appears most aligned with viewer consumption patterns. Improving data completeness would further strengthen analytical accuracy and support better content strategy decisions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
